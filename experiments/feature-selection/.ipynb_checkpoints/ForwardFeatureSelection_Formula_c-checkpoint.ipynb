# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures


from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.metrics import confusion_matrix, classification_report
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
X = pd.read_csv('../datasets/wine_formula_c.csv')
X
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       ...  total_sulfur_dioxide*density  total_sulfur_dioxide*pH  \
# 0     ...                     170.17000                   510.00
# 1     ...                     131.20800                   435.60
# 2     ...                      96.52470                   316.22
# 3     ...                     185.18160                   593.34
# 4     ...                     185.18160                   593.34
# ...   ...                           ...                      ...
# 4893  ...                      91.18488                   300.84
# 4894  ...                     167.14320                   529.20
# 4895  ...                     110.17194                   331.89
# 4896  ...                     108.75590                   367.40
# 4897  ...                      96.96218                   319.48
#
#       total_sulfur_dioxide*sulphates  total_sulfur_dioxide*alcohol  \
# 0                              76.50                        1496.0
# 1                              64.68                        1254.0
# 2                              42.68                         979.7
# 3                              74.40                        1841.4
# 4                              74.40                        1841.4
# ...                              ...                           ...
# 4893                           46.00                        1030.4
# 4894                           77.28                        1612.8
# 4895                           51.06                        1043.4
# 4896                           41.80                        1408.0
# 4897                           31.36                        1156.4
#
#       density*pH  density*sulphates  density*alcohol  pH*sulphates  \
# 0       3.003000           0.450450         8.808800        1.3500
# 1       3.280200           0.487060         9.443000        1.6170
# 2       3.244026           0.437844        10.050510        1.4344
# 3       3.175964           0.398240         9.856440        1.2760
# 4       3.175964           0.398240         9.856440        1.2760
# ...          ...                ...              ...           ...
# 4893    3.241028           0.495570        11.100768        1.6350
# 4894    3.133935           0.457654         9.551040        1.4490
# 4895    2.967695           0.456568         9.329876        1.3754
# 4896    3.302225           0.375702        12.655232        1.2692
# 4897    3.225477           0.316611        11.675038        1.0432
#
#       pH*alcohol  sulphates*alcohol
# 0         26.400              3.960
# 1         31.350              4.655
# 2         32.926              4.444
# 3         31.581              3.960
# 4         31.581              3.960
# ...          ...                ...
# 4893      36.624              5.600
# 4894      30.240              4.416
# 4895      28.106              4.324
# 4896      42.752              4.864
# 4897      38.468              3.776
#
# [4898 rows x 66 columns]

# %%
df = pd.read_csv('../datasets/winequality-white.csv', sep=';')
# df = pd.read_csv("https://raw.githubusercontent.com/SahilSinhaLpu/Machine-Learning/master/Datasets/SomvervilleHappines.csv")
df

### Speaker DS
# Y = df['language']

### Algerian DS
# Y = df['Classes']

### Banknote DS
# Y = df['Class']

### User knowledge DS
# Y = df['UNS']

## Wine quality DS
Y = df['quality']

### Somerville DS
# Y = df['D']

## Pima Indians Diabetes DS
# Y = df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15)

# %% [markdown]
# ### KNN

# %%
# %%time
plain_sfs = SFS(KNeighborsClassifier(), 
          k_features=(1, 10), 
          forward=True, 
          floating=False,
          scoring='accuracy', 
          cv=10)

plain_sfs.fit(X, Y)
# Out:
# CPU times: user 1min 22s, sys: 325 ms, total: 1min 22s
# Wall time: 1min 23s
# SequentialFeatureSelector(cv=10, estimator=KNeighborsClassifier(),
#                           k_features=(1, 10), scoring='accuracy')

# %%
selected_features = X.columns[list(plain_sfs.k_feature_idx_)]
x_t = X_train[selected_features]
clf = KNeighborsClassifier()
clf.fit(x_t, y_train)
print(cross_val_score(clf, x_t, y_train, cv=10).mean())
# Out:
# 0.5459947426674046

# %% [markdown]
# ### Logistic Regression

# %%
plain_sfs_lr = SFS(LogisticRegression(), 
          k_features=(1, 10), 
          forward=True, 
          floating=False, 
          cv=10)

plain_sfs_lr.fit(X, Y)

selected_features = X.columns[list(plain_sfs_lr.k_feature_idx_)]
x_t = X_train[selected_features]
clf = LogisticRegression()
clf.fit(x_t, y_train)

print(cross_val_score(clf, x_t, y_train, cv=10).mean())
# Out:
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# 0.5191074063825862

# %% [markdown]
# ### Naive Bayes

# %%
naive_bayes = GaussianNB()
plain_sfs_nb = SFS(naive_bayes, 
          k_features=(1, 10), 
          forward=True, 
          floating=False, 
          cv=10)

plain_sfs_nb.fit(X, Y)
# Out:
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# SequentialFeatureSelector(cv=10, estimator=GaussianNB(), k_features=(1, 10))

# %%
selected_features = X.columns[list(plain_sfs_nb.k_feature_idx_)]
x_t = X_train[selected_features]
clf = GaussianNB()
clf.fit(x_t, y_train)
print(cross_val_score(clf, x_t, y_train, cv=10).mean())
# Out:
# 0.5200602979155138

# %% [markdown]
# ### SVM

# %%
plain_sfs_svm = SFS(svm.SVC(kernel='linear'), 
          k_features=(1, 10), 
          forward=True, 
          floating=False, 
          cv=10)
plain_sfs_svm.fit(X, Y)
# Out:
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-57d201f063e4> in <module>
#       4           floating=False,
#       5           cv=10)
# ----> 6 plain_sfs_svm.fit(X, Y)
#
# /opt/anaconda3/lib/python3.8/site-packages/mlxtend/feature_selection/sequential_feature_selector.py in fit(self, X, y, custom_feature_names, groups, **fit_params)
#     566                     best_subset = k
#     567             k_score = max_score
# --> 568             k_idx = self.subsets_[best_subset]['feature_idx']
#     569
#     570             if self.k_features == 'parsimonious':
#
# KeyError: None

# %%
selected_features = X.columns[list(plain_sfs_svm.k_feature_idx_)]
x_t = X_train[selected_features]
clf = svm.SVC(kernel='linear')
clf.fit(x_t, y_train)
print(cross_val_score(clf, x_t, y_train, cv=10).mean())
