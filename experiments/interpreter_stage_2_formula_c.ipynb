# %% [markdown]
# # Stage 2 a * b

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
X_full = pd.read_csv('./datasets/diabetes_formula_c.csv')
X_full
# Out:
#      Pregnancies  Glucoze  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Pregnancies*Glucoze  \
# 0                       0.627   50                888.0
# ...

# %%
# data= pd.read_csv("https://raw.githubusercontent.com/SahilSinhaLpu/Machine-Learning/master/Datasets/SomvervilleHappines.csv")
data = pd.read_csv("datasets/diabetes.csv")
data.isnull().sum().sum()
data
# Out:
#      Pregnancies  Glucoze  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
y = data['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_full, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ### KNN

# %%
reg_knn = KNeighborsClassifier()
reg_knn.fit(X_train, y_train)
# y_pred = reg_knn.predict(X_test)
# print(metrics.classification_report(y_test, y_pred))
print("####### CROSS VAL SCORE #######")
print(cross_val_score(reg_knn, X_full, y, cv=10, scoring='accuracy').mean())
# Out:
# ####### CROSS VAL SCORE #######
# 0.7278195488721806

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
reg_log = LogisticRegression()
reg_log.fit(X_train, y_train)
# y_pred = reg_log.predict(X_test)
# print(metrics.classification_report(y_test, y_pred))
# print("####### CROSS VAL SCORE #######")
print(cross_val_score(reg_log, X_full, y, cv=10, scoring='accuracy').mean())
# Out:
# 0.7030416951469582

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
reg_rf = GaussianNB()
reg_rf.fit(X_train, y_train)
# y_pred = reg_rf.predict(X_test)
# print(metrics.classification_report(y_test, y_pred))
print("####### CROSS VAL SCORE #######")
print(cross_val_score(reg_rf, X_full, y, cv=10, scoring='accuracy').mean())
# Out:
# ####### CROSS VAL SCORE #######
# 0.7252904989747095

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
reg_svc = SVC(kernel='linear')
reg_svc.fit(X_train, y_train)
# y_pred = reg_svc.predict(X_test)
# print(metrics.classification_report(y_test, y_pred))
print("####### CROSS VAL SCORE #######")
print(cross_val_score(reg_svc, X_full, y, cv=10, scoring='accuracy').mean())
